# %% [markdown]
# # Statistics

# %%
import pandas as pd

# %%
df= pd.read_excel(r"C:\Users\nikhi\Downloads\weather_data_XL.xlsx")
df
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01    Hyderbad             28          60     Sunny
# 1 2025-01-02    Hyderbad             29          62     Sunny
# 2 2025-01-03    Hyderbad             30          58    Cloudy
# 3 2025-01-04    Hyderbad             31          55    Cloudy
# 4 2025-01-05    Banglore             32          57     Rainy
# 5 2025-01-06    Banglore             33          59     Rainy
# 6 2025-01-07    Banglore             34          61     Sunny
# 7 2025-01-08    Banglore             32          63    Cloudy
# 8 2025-01-09  Vijayawada             31          64     Rainy
# 9 2025-01-10  Vijayawada             29          62     Sunny

# %%
df['Temperature_C'].max()
# Out:
# 34

# %%
df['Temperature_C'].min()
# Out:
# 28

# %%
df['Temperature_C'].std()
# Out:
# 1.911950719959998

# %%
df['Temperature_C'].mean()
# Out:
# np.float64(30.9)

# %%
df.City[df.Temperature_C==df.Temperature_C.max()]
# Out:
# 6    Banglore
# Name: City, dtype: object

# %%
df[df.Temperature_C==df.Temperature_C.max()]
# Out:
#         Date      City  Temperature_C  Humidity_% Condition
# 6 2025-01-07  Banglore             34          61     Sunny

# %%
df.count()
# Out:
# Date             10
# City             10
# Temperature_C    10
# Humidity_%       10
# Condition        10
# dtype: int64

# %%
df["City"].value_counts()
# Out:
# City
# Hyderbad      4
# Banglore      4
# Vijayawada    2
# Name: count, dtype: int64

# %% [markdown]
# # String Cleaning

# %%
df
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01    Hyderbad             28          60     Sunny
# 1 2025-01-02    Hyderbad             29          62     Sunny
# 2 2025-01-03    Hyderbad             30          58    Cloudy
# 3 2025-01-04    Hyderbad             31          55    Cloudy
# 4 2025-01-05    Banglore             32          57     Rainy
# 5 2025-01-06    Banglore             33          59     Rainy
# 6 2025-01-07    Banglore             34          61     Sunny
# 7 2025-01-08    Banglore             32          63    Cloudy
# 8 2025-01-09  Vijayawada             31          64     Rainy
# 9 2025-01-10  Vijayawada             29          62     Sunny

# %%
df["City"]=df["City"].str.lower()
df
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01    hyderbad             28          60     Sunny
# 1 2025-01-02    hyderbad             29          62     Sunny
# 2 2025-01-03    hyderbad             30          58    Cloudy
# 3 2025-01-04    hyderbad             31          55    Cloudy
# 4 2025-01-05    banglore             32          57     Rainy
# 5 2025-01-06    banglore             33          59     Rainy
# 6 2025-01-07    banglore             34          61     Sunny
# 7 2025-01-08    banglore             32          63    Cloudy
# 8 2025-01-09  vijayawada             31          64     Rainy
# 9 2025-01-10  vijayawada             29          62     Sunny

# %%
df["City"]=df["City"].str.upper()
df
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01    HYDERBAD             28          60     Sunny
# 1 2025-01-02    HYDERBAD             29          62     Sunny
# 2 2025-01-03    HYDERBAD             30          58    Cloudy
# 3 2025-01-04    HYDERBAD             31          55    Cloudy
# 4 2025-01-05    BANGLORE             32          57     Rainy
# 5 2025-01-06    BANGLORE             33          59     Rainy
# 6 2025-01-07    BANGLORE             34          61     Sunny
# 7 2025-01-08    BANGLORE             32          63    Cloudy
# 8 2025-01-09  VIJAYAWADA             31          64     Rainy
# 9 2025-01-10  VIJAYAWADA             29          62     Sunny

# %%
df["City"]=df["City"].str.replace("HYDERBAD","CHENNAI")
df
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01     CHENNAI             28          60     Sunny
# 1 2025-01-02     CHENNAI             29          62     Sunny
# 2 2025-01-03     CHENNAI             30          58    Cloudy
# 3 2025-01-04     CHENNAI             31          55    Cloudy
# 4 2025-01-05    BANGLORE             32          57     Rainy
# 5 2025-01-06    BANGLORE             33          59     Rainy
# 6 2025-01-07    BANGLORE             34          61     Sunny
# 7 2025-01-08    BANGLORE             32          63    Cloudy
# 8 2025-01-09  VIJAYAWADA             31          64     Rainy
# 9 2025-01-10  VIJAYAWADA             29          62     Sunny

# %% [markdown]
# # Concate DataFrames

# %%
india_weather = pd.DataFrame({
    "city":["mumbai","banglore","Hyderbad"],
    "Temperature":[32,45,35]
})
india_weather
# Out:
#        city  Temperature
# 0    mumbai           32
# 1  banglore           45
# 2  Hyderbad           35

# %%
US_weather=pd.DataFrame({
    "city":["New york","chicago","orlando"],
    "Temperature":[32,45,35]
})
US_weather
# Out:
#        city  Temperature
# 0  New york           32
# 1   chicago           45
# 2   orlando           35

# %%
df=pd.concat([india_weather,US_weather],ignore_index=True)
df
# Out:
#        city  Temperature
# 0    mumbai           32
# 1  banglore           45
# 2  Hyderbad           35
# 3  New york           32
# 4   chicago           45
# 5   orlando           35

# %%
df=pd.concat([india_weather,US_weather],axis=1)
df
# Out:
#        city  Temperature      city  Temperature
# 0    mumbai           32  New york           32
# 1  banglore           45   chicago           45
# 2  Hyderbad           35   orlando           35

# %% [markdown]
# # Merge DataFrames

# %%
temp_df=pd.DataFrame({
    "city":["hyderabad","Vijayawada","Viskhapatnam","Chennai"],
    "temperature":[32,45,30,35]
})
temp_df
# Out:
#            city  temperature
# 0     hyderabad           32
# 1    Vijayawada           45
# 2  Viskhapatnam           30
# 3       Chennai           35

# %%
humidity_df=pd.DataFrame({
    "city":["hyderabad","Vijayawada","Viskhapatnam","banglore"],
    "humidity":[62,65,60,75]
})
humidity_df
# Out:
#            city  humidity
# 0     hyderabad        62
# 1    Vijayawada        65
# 2  Viskhapatnam        60
# 3      banglore        75

# %%
df=pd.merge(temp_df,humidity_df,on="city")
df
# Out:
#            city  temperature  humidity
# 0     hyderabad           32        62
# 1    Vijayawada           45        65
# 2  Viskhapatnam           30        60

# %%
df=pd.merge(temp_df,humidity_df,on="city",how="outer")
df
# Out:
#            city  temperature  humidity
# 0       Chennai         35.0       NaN
# 1    Vijayawada         45.0      65.0
# 2  Viskhapatnam         30.0      60.0
# 3      banglore          NaN      75.0
# 4     hyderabad         32.0      62.0

# %%
df.isnull()#to find null values / missing values
# Out:
#     city  temperature  humidity
# 0  False        False      True
# 1  False        False     False
# 2  False        False     False
# 3  False         True     False
# 4  False        False     False

# %%
df.isnull().sum()
# Out:
# city           0
# temperature    1
# humidity       1
# dtype: int64

# %%
df
# Out:
#            city  temperature  humidity
# 0       Chennai         35.0       NaN
# 1    Vijayawada         45.0      65.0
# 2  Viskhapatnam         30.0      60.0
# 3      banglore          NaN      75.0
# 4     hyderabad         32.0      62.0

# %%
df["temperature"]=df["temperature"].fillna(30)

# %%
df
# Out:
#            city  temperature  humidity
# 0       Chennai         35.0       NaN
# 1    Vijayawada         45.0      65.0
# 2  Viskhapatnam         30.0      60.0
# 3      banglore         30.0      75.0
# 4     hyderabad         32.0      62.0

# %%
df["humidity"]=df["humidity"].fillna(df.temperature.min())

# %%
df.isnull()
# Out:
#     city  temperature  humidity
# 0  False        False     False
# 1  False        False     False
# 2  False        False     False
# 3  False        False     False
# 4  False        False     False

# %%
df
# Out:
#            city  temperature  humidity
# 0       Chennai         35.0      30.0
# 1    Vijayawada         45.0      65.0
# 2  Viskhapatnam         30.0      60.0
# 3      banglore         30.0      75.0
# 4     hyderabad         32.0      62.0
